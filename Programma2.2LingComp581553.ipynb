# %%
#Programma 2 progetto di Linguistica Computazionale di Lavinia Rotellini, matricola: 581553, a.a. 2023-2024 
#Importo e scarico i moduli che serviranno
import nltk
import math

nltk.download('punkt')
nltk.download('maxent_ne_chunker')
nltk.download('words')

from nltk import FreqDist, ngrams
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

#Assegno il lemmatizzatore ad una variabile per snellire il codice
lemmatizer = WordNetLemmatizer() 

#Il corpus che analizzerò
file = "OECDEdu.txt" #il corpus che analizzeremo


#LETTURA FILE
def read_file(file_path):
  with open (file_path, "r", encoding= "utf-8") as infile:
    contents = infile.read()
  return contents 


#RACCOLTA DELLE FRASI, DEI TOKEN, POS TAGGING E LEMMATIZZAZIONE DEI TESTI

#Nella funzione sotto divido il testo in frasi e token, poi realizzo il POS tagging
def analizing(text):
  sentences = nltk.tokenize.sent_tokenize(text)
  tot_tokens = []
  tot_POS = []
  for sentence in sentences:
    tokens = nltk.tokenize.word_tokenize(sentence)
    tot_tokens.extend(tokens)
    POS = nltk.tag.pos_tag(tokens)
    tot_POS.extend(POS)
  return sentences, tot_tokens, tot_POS

#Questa seconda funzione serve a trasformare la treebank delle parts of speech in una treebank leggibile secondo WordNet
def get_wordnet_pos(treebank_tag):
  if treebank_tag.startswith('J'):
    return wordnet.ADJ

  if treebank_tag.startswith('V'):
    return wordnet.VERB

  if treebank_tag.startswith('N'):
    return wordnet.NOUN

  if treebank_tag.startswith('R'):
    return wordnet.ADV

  else:
    return wordnet.NOUN

#Con la prossima funzione eseguo la funzione di analisi e individuo i lemmi
def main(file_path):
  text = read_file(file_path)
  sentences, tot_tokens, tot_POS= analizing(text)
  lemmatizzazione = [lemmatizer.lemmatize(word, get_wordnet_pos(POS)) for word, POS in tot_POS]
  return sentences, tot_tokens, tot_POS, lemmatizzazione

file_sentences, file_tokens, file_POS, file_lemma = main(file)

#LEMMATIZZAZIONE, così da avere una lista di tuple in cui abbiamo il token affiancato al lemma
def lemmatizzazione(tokens, lemmi):
  lemmatizzazione = list(zip(tokens, lemmi))
  print(f"La lista token/lemmi del testo: {lemmatizzazione}")

lemmatizzazione(file_tokens, file_lemma)

###PUNTO UNO###
##CINQUANTA SOSTANTIVI, AVVERBI ED AGGETTIVI PIU' FREQUENTI

#La funzione sotto trova tutte le istanze di sostantivo, avverbio e aggettivo
def find_POS(list_of_POS, list_of_elements):
  lista_specifica_POS = []
  for token, POS in list_of_elements: #scorriamo la lista delle parts of speech
    if POS in list_of_POS:            #se il pos nella lista è dentro l'altro parametro list of POS, inseriamo nella lista la tupla token, POS
      lista_specifica_POS.append((token, POS))
  return lista_specifica_POS

tag_sostantivi = ["NN", "NNS", "NNP", "NNPS"]         #usiamo queste liste per controllare e prendere i POS con tag dei sostantivi
lista_sostantivi = find_POS(tag_sostantivi, file_POS) #chiamiamo la funzione che ritorna la lista di sostantivi
freq_sostantivi = FreqDist(lista_sostantivi)          #calcoliamo la frequenza assoluta, il processo si ripete per aggettivi e avverbi

tag_aggettivi = ["JJ", "JJR", "JJS"]
lista_aggettivi = find_POS(tag_aggettivi, file_POS)
freq_aggettivi = FreqDist(lista_aggettivi)

tag_avverbi = [ "RB", "RBR", "RBS", "WRB"]
lista_avverbi = find_POS(tag_avverbi, file_POS)
freq_avverbi = FreqDist(lista_avverbi)

#La funzione sotto trova i cinquanta POS più comuni e li stampa
def lista_POS(lista_POS, top_n = 50):                
   for POS, freq in lista_POS.most_common(top_n):
      print(f"Part of speech: {POS} Frequenza assoluta: {freq}")

#Chiamo la funzione precedente sulle liste di sostantivi, aggettivi e avverbi
lista_POS(freq_sostantivi, top_n = 50)              
lista_POS(freq_aggettivi, top_n = 50)
lista_POS(freq_avverbi, top_n = 50)


###PUNTO DUE###
##VENTI NGRAMMI PIU' FREQUENTI

#Inizio con la divisione del testo in ngrammi
ngrams_1 = list(nltk.ngrams(file_tokens, 1))
ngrams_2 = list(nltk.ngrams(file_tokens, 2))
ngrams_3 = list(nltk.ngrams(file_tokens, 3))
ngrams_4 = list(nltk.ngrams(file_tokens, 4))
ngrams_5 = list(nltk.ngrams(file_tokens, 5)) 

#La funzione sotto individua e stampa i venti ngrammi più frequenti
def top_20_ngrams(ngrams, top_n = 20):
  freq_ngrammi = FreqDist(ngrams)
  for ngram, freq in freq_ngrammi.most_common(top_n):
    print(f"Ngramma: {ngram} \n\tFrequenza assoluta: {freq}\n")

top_20_ngrams(ngrams_1, top_n = 20)
top_20_ngrams(ngrams_2, top_n = 20)
top_20_ngrams(ngrams_3, top_n = 20)
top_20_ngrams(ngrams_4, top_n = 20)
top_20_ngrams(ngrams_5, top_n = 20)


###PUNTO TRE###
##VENTI NGRAMMI DI POS PIU' FREQUENTI

#Con il ciclo sotto prendiamo le POS senza token e le inseriamo in una lista
just_POS = []
for token, POS in file_POS: #prendiamo solo le parts of speech senza token e le inseriamo in una lista
   just_POS.append(POS)

#Dividiamo la lista di POS in unigrammi, bigrammi, trigrammi
ngrams_POS_1 = list(nltk.ngrams(just_POS, 1))
ngrams_POS_2 = list(nltk.ngrams(just_POS, 2))
ngrams_POS_3 = list(nltk.ngrams(just_POS, 3))

#Con la funzione sotto troviamo i primi venti ngrammi di POS per frequenza
def top_20_ngrams_POS(ngrams_POS, top_n = 20):
  freq_ngrammi_POS = FreqDist(ngrams_POS)
  for ngram_POS, freq in freq_ngrammi_POS.most_common(top_n):
    print(f"Ngramma: {ngram_POS} \n\tFrequenza assoluta: {freq}\n")

top_20_ngrams_POS(ngrams_POS_1, top_n= 20)
top_20_ngrams_POS(ngrams_POS_2, top_n= 20)
top_20_ngrams_POS(ngrams_POS_3, top_n= 20)


###PUNTO QUATTRO###
##DIECI BIGRAMMI AGGETTIVO SOSTANTIVO PIU' FREQUENTI

#Con il ciclo sotto estraimo le coppie di token aggettivo/sostantivo e le inseriamo in una lista
adj_noun_tuples = []                                                   
for i in range(len(file_POS)-1):
  if file_POS[i][1] in tag_aggettivi and file_POS[i+1][1] in tag_sostantivi:
    adj_noun_tuples.append((file_POS[i][0], file_POS[i+1][0]))
       
#La funzione sotto restituisce i primi dieci bigrammi in ordine di frequenza massima
def adj_noun_couples(list_of_bigrams, top_n = 10):                     
   freq_bigrammi_ADNO = FreqDist(list_of_bigrams)
   for bigram, freq in freq_bigrammi_ADNO.most_common(top_n):
      print(f"Bigrammi: {bigram} \n\tFrequenza assoluta in ordine decrescente: {freq}")

adj_noun_couples(adj_noun_tuples, top_n = 10)

###I primi dieci bigrammi per probabilità condizionata, congiunta, mutual information e local mutual information###

#La funzione sotto prende una lista, mette gli elementi in ordine decrescente e ne prende i primi dieci
def top_10(list_of_elements, funzione):
  sort_elements = sorted(list_of_elements,key=lambda item: item[1], reverse=True)
  print(f"Top 10 bigrammi per {funzione}: \n\t {sort_elements[:10]}\n")
  return sort_elements[:10]

#La funzione sotto prende in input un'altra funzione ed una lista di elementi, oltre al numero totale di bigrammi e token,
#e ad ogni elemento della lista applica la funzione. Restituisce una lista, a cui sarà applicata la funzione top 10 sopra
def liste(lista, funzione, tot_bigrams, tot_tokens):
  totale_elementi = []
  for element in lista:
    risultato = funzione(element, tot_bigrams, tot_tokens)
    totale_elementi.append((element, risultato))
  return totale_elementi

#Creo una funzione che calcoli la probabilità condizionata
def probabilita_condizionata(bigram, tot_bigrams, tot_tokens):
  freq_bigramma = tot_bigrams.count(bigram)
  tot_elem_1 = tot_tokens.count(bigram[0])
  prob_condizionata = freq_bigramma/tot_elem_1
  return prob_condizionata

#Chiamo la funzione <liste> nella quale utilizzo la funzione <probabilita_condizionata> così da calcolarla su ogni elemento della lsta di tuple aggettivo/sostantivo
elem_prob_condizionata = liste(adj_noun_tuples, probabilita_condizionata, ngrams_2, file_tokens)

#Chiamo la funzione top_10 per trovare e stampare i primi 10 elementi per probabilità condizionata
top_10(elem_prob_condizionata, funzione = "probabilità condizionata")


#Adesso creo una funziona che calcoli la probabilità congiunta        
def probabilità_congiunta(bigram, tot_bigrams, tot_tokens):
  prob_cond = probabilita_condizionata(bigram, tot_bigrams, tot_tokens) #calcolo la probabilità condizionata usando la funzione precedente
  freq_elem_1 = tot_tokens.count(bigram[0])                             #calcolo la frequenza dell'elemento 1  
  prob_elem_1 = freq_elem_1/len(tot_tokens)                             #e la probabilità dell'elemento 1
  prob_congiunta = prob_cond * prob_elem_1                              #calcolo la probabilità congiunta
  return prob_congiunta

#Creo la lista di bigrammi con associata la funzione <probabilità_congiunta>
elem_prob_congiunta = liste(adj_noun_tuples, probabilità_congiunta, ngrams_2, file_tokens) #creiamo la lista di bigrammi con associata la prob congiunta

#Chiamo la funzione top_10
top_10(elem_prob_congiunta, funzione = "probabilità congiunta")


#Adesso creo una funziona che calcoli la mutual information
def MI(bigram, tot_bigrams, tot_tokens):
  freq_bigramma = tot_bigrams.count(bigram)
  
  freq_elem_1 = tot_tokens.count(bigram[0])
  freq_elem_2 = tot_tokens.count(bigram[1])
  
  MI = math.log((freq_bigramma*len(tot_tokens)/(freq_elem_1*freq_elem_2)), 2)   
  return MI

elem_MI = liste(adj_noun_tuples, MI, ngrams_2, file_tokens)              #creo la lista dei bigrammi con la loro MI
top10_MI = top_10(elem_MI, funzione = "mutual information") 

def LMI(bigram, tot_bigrams, tot_tokens):
  freq_bigramma = tot_bigrams.count(bigram)
  
  mutual_info = MI(bigram, tot_bigrams, tot_tokens)
  LMI = freq_bigramma * mutual_info    
  return LMI

  
elem_LMI = liste(adj_noun_tuples, LMI, ngrams_2, file_tokens)             #creo la lista dei bigrammi con relativa LMI
top10_LMI = top_10(elem_LMI, funzione = "local mutual information")       #ne stampo i primi dieci elementi


#La funzione sotto trova gli elementi in comune nelle liste di MI e LMI e li stampa, se ci sono
def elem_comuni_MI_LMI(MI_list, LMI_list):
  elem_comuni = []
  for elem in MI_list:
    for i in LMI_list:
      if elem[0] in i[0]:
        elem_comuni.append(elem)
  if len(elem_comuni) > 0:
    print(elem_comuni)
  else:
    print("Non ci sono elementi in comune")


elem_comuni_MI_LMI(top10_MI, top10_LMI)
        

###PUNTO CINQUE###
####MEDIA DELLE DISTRIBUZIONI DI FREQUENZA E MODELLO DI MARKOV

#Trovo le frasi con una lunghezza tra i dieci e venti caratteri
def frasi(sentences):
  sentences_10_20 = []
  for sentence in sentences:
    tokens = nltk.tokenize.word_tokenize(sentence)
    if 10<=len(tokens)<=20:
      sentences_10_20.append(sentence)
  return sentences_10_20

sentences_10_20 = frasi(file_sentences)

#Trovo gli hapax
def hapax(tokens):   
    hapax = []        
    vocab = list(set(tokens))       
    for token in vocab:        
        token_freq = tokens.count(token)
        if token_freq == 1:
          hapax.append(token) 
    return hapax
            
tot_hapax = hapax(file_tokens)

#Trovo le frasi nelle quali almeno la metà dei token compare due volte nel corpus
def frasi_few_hapax(sentences, tot_hapax):
  frasi = []
  for sentence in sentences:
    hapax_count = sum(sentence.count(token) for token in tot_hapax)
    if hapax_count < (len(sentence)/2):
      frasi.append(sentence)
  return frasi

frasi_no_hapax = frasi_few_hapax(sentences_10_20, tot_hapax)

#Faccio la media di distribuzione delle frequenze
def media_freq_token(sentences):
  tot_frequenze = []
  for sentence in sentences:
    tokens = nltk.tokenize.word_tokenize(sentence)
    freq_tot_token = FreqDist(tokens) 
    freq_media = sum(freq_tot_token.values())/len(tokens) 
    tot_frequenze.append((sentence, freq_media))
  return tot_frequenze

tot_frequenze = media_freq_token(frasi_no_hapax)

def media_max_min(list_of_tuples):
  frequenza_max = max(list_of_tuples, key = lambda x: x[1])
  frequenza_min = min(list_of_tuples, key = lambda x: x[1])
  print(f"Il valore massimo di frequenza media appartiene alla frase: {frequenza_max[0]}, con un valore di {frequenza_max[1]}")
  print(f"Il valore minimo di frequenza media appartiene alla frase: {frequenza_min[0]}, con un valore di {frequenza_min[1]}")
     
media_max_min(tot_frequenze)

#Modello markoviano del secondo ordine

#Trovo le frequenze di distribuzione dei token, trigrammie bigrammi
freq_tokens = nltk.FreqDist(file_tokens)
trigrams_freq_dist = nltk.FreqDist(ngrams_3)
bigrams_freq_dist = nltk.FreqDist(ngrams_2)

#La funzione sotto calcola la probabilità condizionata e sarà riusata nella funzione del modello di markov
def conditional_probability(trigram, distribuzione_freq_trigrammi, distribuzione_freq_bigrammi):
  if distribuzione_freq_bigrammi[(trigram[0], trigram[1])] == 0:
    conditional_prob = 0
  else:
    conditional_prob = distribuzione_freq_trigrammi[trigram]/distribuzione_freq_bigrammi[(trigram[0], trigram[1])]
  return conditional_prob

#La funzione sotto calcola la probabilità secondo un modello di markov di ordine 2
def markov_2(sentence, distribuzione_freq_trigrammi, distribuzione_freq_bigrammi, distribuzione_freq_tokens, corpus):
  tokens = nltk.tokenize.word_tokenize(sentence)
  trigrams_in_sentence = list(nltk.ngrams(tokens, 3))
    
  prob = 1.0*(distribuzione_freq_bigrammi[(tokens[0], tokens[1])]/distribuzione_freq_tokens[tokens[0]]) * (distribuzione_freq_tokens[tokens[0]]/corpus)
    
  for trigram in trigrams_in_sentence:
      cond_prob = conditional_probability(trigram, distribuzione_freq_trigrammi, distribuzione_freq_bigrammi)
      prob = prob*cond_prob
  return prob

#Calcolo la probabilità di ogni frase con il modello di markov
def f(sentences, distribuzione_freq_trigrammi, distribuzione_freq_bigrammi, distribuzione_freq_tokens):
  frasi_markov = []
  for sentence in sentences:
    prob = markov_2(sentence, distribuzione_freq_trigrammi, distribuzione_freq_bigrammi, distribuzione_freq_tokens, len(file_tokens))
    frasi_markov.append((sentence, prob))
  return frasi_markov

frasi_markov = f(sentences_10_20, trigrams_freq_dist, bigrams_freq_dist, freq_tokens)

#Trovo e stampo la frase con la probabilità maggiore e minore
def markov_max_min(list_of_tuples):
  prob_max = max(list_of_tuples, key = lambda x: x[1])
  prob_min = min(list_of_tuples, key = lambda x: x[1])
  print(f"La probabilità massima secondo il Modello di Markov di ordine due appartiene alla frase: {prob_max[0]}, con un valore di {prob_max[1]}")
  print(f"La probabilità minima secondo il Modello di Markov di ordine due appartiene alla frase: {prob_min[0]}, con un valore di {prob_min[1]}")
     
markov_max_min(frasi_markov)


###PUNTO SEI###
##ESTRAZIONE DELLE NAME ENTITIES E TOP 15 ELEMENTI PIU' FREQUENTI

#Trovo l'aòbero delle name entities a partire dalla lista delle part of speech del file
NE_tree = nltk.ne_chunk(file_POS)          

#Inizializzo un dizionario vuoto in cui mettere come chiavi le name entities e come valori le istanze di quella classe di NE
NE = {}      

#Per ogni nodo nell'albero di NE individuo le NE e le loro istanze, poi le inserisco nel dizionario se non ci sono di già                                   
for nodo in NE_tree: 
    if hasattr(nodo, 'label'): 
        entity_type = nodo.label() 
        entity = " ".join([token for token, POS in nodo.leaves()]) 
        if entity_type in NE.keys():           
            NE[entity_type].append(entity) 
        else:
            NE[entity_type] = [entity]  

#Creo delle liste che contengono solo i valori delle chiave del dizionario, ovvero le istanze delle classi di NE
person = NE['PERSON']                          
org = NE['ORGANIZATION']
GPE = NE['GPE']

#La funzione sotto calcola le frequenze delle istanze nelle classi create nello step precedente e stampa le 15 più frequenti
def top_15_NE(lista, entity_type, top_n = 15): 
   freq_NE = FreqDist(lista)
   for entity, freq in freq_NE.most_common(top_n):
      print(f"{entity_type}: {entity} \n\tFrequenza assoluta: {freq}")

top_15_NE(person, entity_type = 'PERSON', top_n = 15)
top_15_NE(org, entity_type = 'ORGANIZATION', top_n = 15)
top_15_NE(GPE, entity_type = 'GPE', top_n = 15)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cinna\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\cinna\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\cinna\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# La lista token/lemmi del testo: [('In', 'In'), ('2022', '2022'), (',', ','), ('as', 'a'), ('countries', 'country'), ('were', 'be'), ('still', 'still'), ('dealing', 'deal'), ('with', 'with'), ('the', 'the'), ('lingering', 'linger'), ('impacts', 'impact'), ('of', 'of'), ('the', 'the'), ('COVID-19', 'COVID-19'), ('pandemic', 'pandemic'), (',', ','), ('nearly', 'nearly'), ('700', '700'), ('000', '000'), ('students', 'student'), ('from', 'from'), ('81', '81'), ('OECD', 'OECD'), ('Member', 'Member'), ('and', 'and'), ('partner', 'partner'), ('economies', 'economy'), (',', ','), ('representing', 'represent'), ('29', '29'), ('million', 'million'), ('across', 'across'), ('the', 'the'), ('world', 'world'), (',', ','), ('took', 'take'), ('the', 'the'), ('Programme', 'Programme'), ('for', 'for'), ('International', 'International'), ('Student', 'Student'), ('Assessment', 'Assessment'), ('(', '('), ('PISA', 'PISA'), (')', ')'), ('test', 'test'), ('.', '.'), ('It', 'It'), ('makes', 'make'), ('2022', '2022'), ('PISA', 'PISA'), ('the', 'the'), ('first', 'first'), ('large-scale', 'large-scale'), ('study', 'study'), ('to', 'to'), ('collect', 'collect'), ('data', 'data'), ('on', 'on'), ('student', 'student'), ('performance', 'performance'), (',', ','), ('well-being', 'well-being'), (',', ','), ('and', 'and'), ('equity', 'equity'), ('before', 'before'), ('and', 'and'), ('after', 'after'), ('the', 'the'), ('COVID-19', 'COVID-19'), ('disruptions', 'disruption'), ('.', '.'), ('The', 'The'), ('report', 'report'), ('finds', 'find'), ('that', 'that'), ('in', 'in'), ('spite', 'spite'), ('of', 'of'), ('the', 'the'), ('challenging', 'challenging'), ('circumstances', 'circumstance'), (',', ','), ('31', '31'), ('countries', 'country'), ('and', 'and'), ('economies', 'economy'), ('managed', 'manage'), ('to', 'to'), ('at', 'at'), ('least', 'least'), ('maintain', 'maintain'), ('their', 'their'), ('performance', 'performance'), ('in', 'in'), ('mathematics', 'mathematics'), ('since', 'since'), ('PISA', 'PISA'), ('2018', '2018'), ('.', '.'), ('Among', 'Among'), ('these', 'these'), (',', ','), ('Australia', 'Australia'), ('*', '*'), (',', ','), ('Japan', 'Japan'), (',', ','), ('Korea', 'Korea'), (',', ','), ('Singapore', 'Singapore'), (',', ','), ('and', 'and'), ('Switzerland', 'Switzerland'), ('maintained', 'maintain'), ('or', 'or'), ('further', 'far'), ('raised', 'raise'), ('already', 'already'), ('high', 'high'), ('levels', 'level'), ('of', 'of'), ('student', 'student'), ('performance', 'performance'), (',', ','), ('with', 'with'), ('scores', 'score'), ('ranging', 'range'), ('from', 'from'), ('487', '487'), ('to', 'to'), ('575', '575'), ('points', 'point'), ('(', '('), ('OECD', 'OECD'), ('average', 'average'), ('472', '472'), (')', ')'), ('.', '.'), ('These', 'These'), ('systems', 'system'), ('showed', 'show'), ('common', 'common'), ('features', 'feature'), ('including', 'include'), ('shorter', 'short'), ('school', 'school'), ('closures', 'closure'), (',', ','), ('fewer', 'few'), ('obstacles', 'obstacle'), ('to', 'to'), ('remote', 'remote'), ('learning', 'learning'), (',', ','), ('and', 'and'), ('continuing', 'continue'), ('teachers', 'teacher'), ('’', '’'), ('and', 'and'), ('parental', 'parental'), ('support', 'support'), (',', ','), ('which', 'which'), ('can', 'can'), ('further', 'far'), ('offer', 'offer'), ('insights', 'insight'), ('and', 'and'), ('indications', 'indication'), ('of', 'of'), ('broader', 'broad'), ('best', 'best'), ('practices', 'practice'), ('to', 'to'), ('address', 'address'), ('future', 'future'), ('crises', 'crisis'), ('.', '.'), ('Many', 'Many'), ('countries', 'country'), ('also', 'also'), ('made', 'make'), ('significant', 'significant'), ('progress', 'progress'), ('towards', 'towards'), ('universal', 'universal'), ('secondary', 'secondary'), ('education', 'education'), (',', ','), ('key', 'key'), ('to', 'to'), ('enabling', 'enable'), ('equality', 'equality'), ('of', 'of'), ('opportunity', 'opportunity'), ('and', 'and'), ('full', 'full'), (' ...
# Part of speech: ('countries', 'NNS') Frequenza assoluta: 69
# Part of speech: ('points', 'NNS') Frequenza assoluta: 67
# Part of speech: ('mathematics', 'NNS') Frequenza assoluta: 63
# Part of speech: ('OECD', 'NNP') Frequenza assoluta: 58
# Part of speech: ('performance', 'NN') Frequenza assoluta: 53
# Part of speech: ('*', 'NNP') Frequenza assoluta: 51
# Part of speech: ('students', 'NNS') Frequenza assoluta: 47
# Part of speech: ('PISA', 'NNP') Frequenza assoluta: 42
# Part of speech: ('education', 'NN') Frequenza assoluta: 38
# Part of speech: ('science', 'NN') Frequenza assoluta: 34
# Part of speech: ('score', 'NN') Frequenza assoluta: 34
# Part of speech: ('reading', 'NN') Frequenza assoluta: 33
# Part of speech: ('economies', 'NNS') Frequenza assoluta: 31
# Part of speech: ('average', 'NN') Frequenza assoluta: 28
# Part of speech: ('systems', 'NNS') Frequenza assoluta: 23
# Part of speech: ('%', 'NN') Frequenza assoluta: 21
# Part of speech: ('China', 'NNP') Frequenza assoluta: 19
# Part of speech: ('countries/economies', 'NNS') Frequenza assoluta: 19
# Part of speech: ('Korea', 'NNP') Frequenza assoluta: 15
# Part of speech: ('numeracy', 'NN') Frequenza assoluta: 15
# Part of speech: ('school', 'NN') Frequenza assoluta: 14
# Part of speech: ('student', 'NN') Frequenza assoluta: 13
# Part of speech: ('Singapore', 'NNP') Frequenza assoluta: 13
# Part of speech: ('growth', 'NN') Frequenza assoluta: 13
# Part of speech: ('Japan', 'NNP') Frequenza assoluta: 12
# Part of speech: ('data', 'NNS') Frequenza assoluta: 11
# Part of speech: ('Canada', 'NNP') Frequenza assoluta: 11
# Part of speech: ('Macao', 'NNP') Frequenza assoluta: 11
# Part of speech: ('Taipei', 'NNP') Frequenza assoluta: 11
# Part of speech: ('skills', 'NNS') Frequenza assoluta: 11
# Part of speech: ('levels', 'NNS') Frequenza assoluta: 10
# Part of speech: ('gap', 'NN') Frequenza assoluta: 10
# Part of speech: ('anxiety', 'NN') Frequenza assoluta: 10
# Part of speech: ('[', 'NN') Frequenza assoluta: 10
# Part of speech: (']', 'NN') Frequenza assoluta: 10
# Part of speech: ('Ireland', 'NNP') Frequenza assoluta: 9
# Part of speech: ('Estonia', 'NNP') Frequenza assoluta: 9
# Part of speech: ('learning', 'NN') Frequenza assoluta: 8
# Part of speech: ('Hong', 'NNP') Frequenza assoluta: 8
# Part of speech: ('Kong', 'NNP') Frequenza assoluta: 8
# Part of speech: ('Chinese', 'NNP') Frequenza assoluta: 8
# Part of speech: ('part', 'NN') Frequenza assoluta: 8
# Part of speech: ('15-year-olds', 'NNS') Frequenza assoluta: 7
# Part of speech: ('proficiency', 'NN') Frequenza assoluta: 7
# Part of speech: ('Finland', 'NNP') Frequenza assoluta: 7
# Part of speech: ('United', 'NNP') Frequenza assoluta: 7
# Part of speech: ('Republic', 'NNP') Frequenza assoluta: 7
# Part of speech: ('[', 'NNP') Frequenza assoluta: 7
# Part of speech: (']', 'NNP') Frequenza assoluta: 7
# Part of speech: ('mean', 'NN') Frequenza assoluta: 7
# Part of speech: ('average', 'JJ') Frequenza assoluta: 17
# Part of speech: ('more', 'JJR') Frequenza assoluta: 16
# Part of speech: ('other', 'JJ') Frequenza assoluta: 14
# Part of speech: ('mean', 'JJ') Frequenza assoluta: 13
# Part of speech: ('’', 'JJ') Frequenza assoluta: 9
# Part of speech: ('socio-economic', 'JJ') Frequenza assoluta: 8
# Part of speech: ('least', 'JJS') Frequenza assoluta: 6
# Part of speech: ('high', 'JJ') Frequenza assoluta: 6
# Part of speech: ('such', 'JJ') Frequenza assoluta: 6
# Part of speech: ('available', 'JJ') Frequenza assoluta: 6
# Part of speech: ('positive', 'JJ') Frequenza assoluta: 5
# Part of speech: ('higher', 'JJR') Frequenza assoluta: 5
# Part of speech: ('most', 'JJS') Frequenza assoluta: 5
# Part of speech: ('•', 'JJ') Frequenza assoluta: 5
# Part of speech: ('lowest-performing', 'JJ') Frequenza assoluta: 5
# Part of speech: ('significant', 'JJ') Frequenza assoluta: 4
# Part of speech: ('basic', 'JJ') Frequenza assoluta: 4
# Part of speech: ('negative', 'JJ') Frequenza assoluta: 4
# Part of speech: ('long-term', 'JJ') Frequenza assoluta: 4
# Part of speech: ('young', 'JJ') Frequenza assoluta: 4
# Part of speech: ('highest', 'JJS') Frequenza assoluta: 4
# Part of speech: ('highest-', 'JJ') Frequenza assoluta: 4
# Part of speech: ('new', 'JJ') Frequenza assoluta: 4
# Part of speech: ('fewer', 'JJR') Frequenza assoluta: 3
# Part of speech: ('parental', 'JJ') Frequenza assoluta: 3
# Part of speech: ('full', 'JJ') Frequenza assoluta: 3
# Part of speech: ('large', 'JJ') Frequenza assoluta: 3
# Part of speech: ('same', 'JJ') Frequenza assoluta: 3
# Part of speech: ('greater', 'JJR') Frequenza assoluta: 3
# Part of speech: ('15-year-old', 'JJ') Frequenza assoluta: 3
# Part of speech: ('low', 'JJ') Frequenza assoluta: 3
# Part of speech: ('extra', 'JJ') Frequenza assoluta: 3
# Part of speech: ('s', 'JJ') Frequenza assoluta: 3
# Part of speech: ('mathematical', 'JJ') Frequenza assoluta: 3
# Part of speech: ('proficient', 'JJ') Frequenza assoluta: 3
# Part of speech: ('complex', 'JJ') Frequenza assoluta: 3
# Part of speech: ('Chinese', 'JJ') Frequenza assoluta: 3
# Part of speech: ('highest-performing', 'JJ') Frequenza assoluta: 3
# Part of speech: ('Asian', 'JJ') Frequenza assoluta: 3
# Part of speech: ('better', 'JJR') Frequenza assoluta: 3
# Part of speech: ('essential', 'JJ') Frequenza assoluta: 3
# Part of speech: ('different', 'JJ') Frequenza assoluta: 3
# Part of speech: ('numeracy', 'JJ') Frequenza assoluta: 3
# Part of speech: ('first', 'JJ') Frequenza assoluta: 2
# Part of speech: ('large-scale', 'JJ') Frequenza assoluta: 2
# Part of speech: ('best', 'JJS') Frequenza assoluta: 2
# Part of speech: ('key', 'JJ') Frequenza assoluta: 2
# Part of speech: ('past', 'JJ') Frequenza assoluta: 2
# Part of speech: ('equitable', 'JJ') Frequenza assoluta: 2
# Part of speech: ('unprecedented', 'JJ') Frequenza assoluta: 2
# Part of speech: ('also', 'RB') Frequenza assoluta: 15
# Part of speech: ('not', 'RB') Frequenza assoluta: 14
# Part of speech: ('only', 'RB') Frequenza assoluta: 7
# Part of speech: ('significantly', 'RB') Frequenza assoluta: 6
# Part of speech: ('well', 'RB') Frequenza assoluta: 6
# Part of speech: ('where', 'WRB') Frequenza assoluta: 5
# Part of speech: ('mathematically', 'RB') Frequenza assoluta: 5
# Part of speech: ('as', 'RB') Frequenza assoluta: 5
# Part of speech: ('how', 'WRB') Frequenza assoluta: 5
# Part of speech: ('already', 'RB') Frequenza assoluta: 4
# Part of speech: ('almost', 'RB') Frequenza assoluta: 4
# Part of speech: ('more', 'RBR') Frequenza assoluta: 4
# Part of speech: ('rather', 'RB') Frequenza assoluta: 4
# Part of speech: ('never', 'RB') Frequenza assoluta: 4
# Part of speech: ('statistically', 'RB') Frequenza assoluta: 4
# Part of speech: ('highly', 'RB') Frequenza assoluta: 3
# Part of speech: ('often', 'RB') Frequenza assoluta: 3
# Part of speech: ('even', 'RB') Frequenza assoluta: 3
# Part of speech: ('particularly', 'RB') Frequenza assoluta: 3
# Part of speech: ('once', 'RB') Frequenza assoluta: 3
# Part of speech: ('further', 'RBR') Frequenza assoluta: 2
# Part of speech: ('Yet', 'RB') Frequenza assoluta: 2
# Part of speech: ('prior', 'RB') Frequenza assoluta: 2
# Part of speech: ('up', 'RB') Frequenza assoluta: 2
# Part of speech: ('-Singapore', 'RB') Frequenza assoluta: 2
# Part of speech: ('however', 'RB') Frequenza assoluta: 2
# Part of speech: ('Similarly', 'RB') Frequenza assoluta: 2
# Part of speech: ('better', 'RBR') Frequenza assoluta: 2
# Part of speech: ('still', 'RB') Frequenza assoluta: 1
# Part of speech: ('nearly', 'RB') Frequenza assoluta: 1
# Part of speech: ('average', 'RB') Frequenza assoluta: 1
# Part of speech: ('rapidly', 'RB') Frequenza assoluta: 1
# Part of speech: ('previously', 'RB') Frequenza assoluta: 1
# Part of speech: ('now', 'RB') Frequenza assoluta: 1
# Part of speech: ('partially', 'RB') Frequenza assoluta: 1
# Part of speech: ('so', 'RB') Frequenza assoluta: 1
# Part of speech: ('However', 'RB') Frequenza assoluta: 1
# Part of speech: ('digitally', 'RB') Frequenza assoluta: 1
# Part of speech: ('How', 'WRB') Frequenza assoluta: 1
# Part of speech: ('higher', 'RBR') Frequenza assoluta: 1
# Part of speech: ('autonomously', 'RB') Frequenza assoluta: 1
# Part of speech: ('remotely', 'RB') Frequenza assoluta: 1
# Part of speech: ('substantially', 'RB') Frequenza assoluta: 1
# Part of speech: ('Finally', 'RB') Frequenza assoluta: 1
# Part of speech: ('when', 'WRB') Frequenza assoluta: 1
# Part of speech: ('relatively', 'RB') Frequenza assoluta: 1
# Part of speech: ('Rather', 'RB') Frequenza assoluta: 1
# Part of speech: ('basically', 'RB') Frequenza assoluta: 1
# Part of speech: ('-In', 'RB') Frequenza assoluta: 1
# Part of speech: ('-About', 'RB') Frequenza assoluta: 1
# Ngramma: (',',)
# 	Frequenza assoluta: 298
#
# Ngramma: ('in',)
# 	Frequenza assoluta: 204
#
# Ngramma: ('and',)
# 	Frequenza assoluta: 194
#
# Ngramma: ('the',)
# 	Frequenza assoluta: 179
#
# Ngramma: ('.',)
# 	Frequenza assoluta: 166
#
# Ngramma: ('of',)
# 	Frequenza assoluta: 109
#
# Ngramma: ('(',)
# 	Frequenza assoluta: 76
#
# Ngramma: (')',)
# 	Frequenza assoluta: 76
#
# Ngramma: ('to',)
# 	Frequenza assoluta: 74
#
# Ngramma: ('countries',)
# 	Frequenza assoluta: 69
#
# Ngramma: ('points',)
# 	Frequenza assoluta: 67
#
# Ngramma: ('mathematics',)
# 	Frequenza assoluta: 63
#
# Ngramma: ('OECD',)
# 	Frequenza assoluta: 59
#
# Ngramma: ('*',)
# 	Frequenza assoluta: 56
#
# Ngramma: ('performance',)
# 	Frequenza assoluta: 53
#
# Ngramma: ('students',)
# 	Frequenza assoluta: 47
#
# Ngramma: ('average',)
# 	Frequenza assoluta: 46
#
# Ngramma: ('PISA',)
# 	Frequenza assoluta: 44
#
# Ngramma: ('that',)
# 	Frequenza assoluta: 42
#
# Ngramma: ('is',)
# 	Frequenza assoluta: 39
#
# Ngramma: ('in', 'mathematics')
# 	Frequenza assoluta: 35
#
# Ngramma: ('*', ',')
# 	Frequenza assoluta: 33
#
# Ngramma: ('countries', 'and')
# 	Frequenza assoluta: 32
#
# Ngramma: (')', '.')
# 	Frequenza assoluta: 28
#
# Ngramma: ('and', 'economies')
# 	Frequenza assoluta: 27
#
# Ngramma: (',', 'the')
# 	Frequenza assoluta: 27
#
# Ngramma: ('the', 'OECD')
# 	Frequenza assoluta: 27
#
# Ngramma: ('.', 'In')
# 	Frequenza assoluta: 27
#
# Ngramma: ('points', ')')
# 	Frequenza assoluta: 27
#
# Ngramma: ('OECD', 'average')
# 	Frequenza assoluta: 21
#
# Ngramma: ('in', 'the')
# 	Frequenza assoluta: 21
#
# Ngramma: ('OECD', 'countries')
# 	Frequenza assoluta: 21
#
# Ngramma: ('PISA', '2022')
# 	Frequenza assoluta: 21
#
# Ngramma: ('education', 'systems')
# 	Frequenza assoluta: 18
#
# Ngramma: ('and', 'science')
# 	Frequenza assoluta: 17
#
# Ngramma: ('average', 'in')
# 	Frequenza assoluta: 17
#
# Ngramma: ('above', 'the')
# 	Frequenza assoluta: 17
#
# Ngramma: ('score', 'points')
# 	Frequenza assoluta: 16
#
# Ngramma: ('performed', 'above')
# 	Frequenza assoluta: 16
#
# Ngramma: ('in', 'PISA')
# 	Frequenza assoluta: 16
#
# Ngramma: ('countries', 'and', 'economies')
# 	Frequenza assoluta: 27
#
# Ngramma: ('the', 'OECD', 'average')
# 	Frequenza assoluta: 19
#
# Ngramma: ('above', 'the', 'OECD')
# 	Frequenza assoluta: 17
#
# Ngramma: ('performed', 'above', 'the')
# 	Frequenza assoluta: 16
#
# Ngramma: ('OECD', 'average', 'in')
# 	Frequenza assoluta: 15
#
# Ngramma: ('in', 'PISA', '2022')
# 	Frequenza assoluta: 14
#
# Ngramma: ('(', 'China', ')')
# 	Frequenza assoluta: 13
#
# Ngramma: (',', 'Japan', ',')
# 	Frequenza assoluta: 12
#
# Ngramma: ('reading', 'and', 'science')
# 	Frequenza assoluta: 12
#
# Ngramma: ('Japan', ',', 'Korea')
# 	Frequenza assoluta: 11
#
# Ngramma: (',', 'Korea', ',')
# 	Frequenza assoluta: 11
#
# Ngramma: ('points', ')', '.')
# 	Frequenza assoluta: 11
#
# Ngramma: ('and', 'Chinese', 'Taipei')
# 	Frequenza assoluta: 10
#
# Ngramma: ('%', 'of', 'students')
# 	Frequenza assoluta: 10
#
# Ngramma: ('across', 'OECD', 'countries')
# 	Frequenza assoluta: 9
#
# Ngramma: ('*', ',', 'Japan')
# 	Frequenza assoluta: 8
#
# Ngramma: (',', 'Ireland', '*')
# 	Frequenza assoluta: 8
#
# Ngramma: ('Macao', '(', 'China')
# 	Frequenza assoluta: 8
#
# Ngramma: ('in', 'mathematics', ',')
# 	Frequenza assoluta: 8
#
# Ngramma: ('Canada', '*', ',')
# 	Frequenza assoluta: 7
#
# Ngramma: ('performed', 'above', 'the', 'OECD')
# 	Frequenza assoluta: 16
#
# Ngramma: ('above', 'the', 'OECD', 'average')
# 	Frequenza assoluta: 16
#
# Ngramma: ('the', 'OECD', 'average', 'in')
# 	Frequenza assoluta: 15
#
# Ngramma: (',', 'Japan', ',', 'Korea')
# 	Frequenza assoluta: 11
#
# Ngramma: ('*', ',', 'Japan', ',')
# 	Frequenza assoluta: 8
#
# Ngramma: ('Japan', ',', 'Korea', ',')
# 	Frequenza assoluta: 8
#
# Ngramma: ('Macao', '(', 'China', ')')
# 	Frequenza assoluta: 8
#
# Ngramma: ('average', 'across', 'OECD', 'countries')
# 	Frequenza assoluta: 7
#
# Ngramma: ('also', 'performed', 'above', 'the')
# 	Frequenza assoluta: 7
#
# Ngramma: ('that', 'took', 'part', 'in')
# 	Frequenza assoluta: 7
#
# Ngramma: ('took', 'part', 'in', 'PISA')
# 	Frequenza assoluta: 7
#
# Ngramma: ('part', 'in', 'PISA', '2022')
# 	Frequenza assoluta: 7
#
# Ngramma: (',', 'reading', 'and', 'science')
# 	Frequenza assoluta: 6
#
# Ngramma: (',', 'Macao', '(', 'China')
# 	Frequenza assoluta: 6
#
# Ngramma: ('countries', 'and', 'economies', ',')
# 	Frequenza assoluta: 6
#
# Ngramma: ('other', 'countries', 'and', 'economies')
# 	Frequenza assoluta: 6
#
# Ngramma: ('OECD', 'average', 'in', 'science')
# 	Frequenza assoluta: 6
#
# Ngramma: ('countries', 'and', 'economies', 'that')
# 	Frequenza assoluta: 6
#
# Ngramma: ('in', 'PISA', '2022', '.')
# 	Frequenza assoluta: 6
#
# Ngramma: ('(', 'mean', 'score', 'of')
# 	Frequenza assoluta: 6
#
# Ngramma: ('performed', 'above', 'the', 'OECD', 'average')
# 	Frequenza assoluta: 16
#
# Ngramma: ('above', 'the', 'OECD', 'average', 'in')
# 	Frequenza assoluta: 15
#
# Ngramma: ('*', ',', 'Japan', ',', 'Korea')
# 	Frequenza assoluta: 8
#
# Ngramma: (',', 'Japan', ',', 'Korea', ',')
# 	Frequenza assoluta: 8
#
# Ngramma: ('also', 'performed', 'above', 'the', 'OECD')
# 	Frequenza assoluta: 7
#
# Ngramma: ('that', 'took', 'part', 'in', 'PISA')
# 	Frequenza assoluta: 7
#
# Ngramma: ('took', 'part', 'in', 'PISA', '2022')
# 	Frequenza assoluta: 7
#
# Ngramma: (',', 'Macao', '(', 'China', ')')
# 	Frequenza assoluta: 6
#
# Ngramma: ('the', 'OECD', 'average', 'in', 'science')
# 	Frequenza assoluta: 6
#
# Ngramma: ('Hong', 'Kong', '(', 'China', ')')
# 	Frequenza assoluta: 5
#
# Ngramma: ('Kong', '(', 'China', ')', '*')
# 	Frequenza assoluta: 5
#
# Ngramma: ('on', 'average', 'across', 'OECD', 'countries')
# 	Frequenza assoluta: 5
#
# Ngramma: ('Japan', ',', 'Korea', ',', 'Macao')
# 	Frequenza assoluta: 5
#
# Ngramma: ('gap', 'in', 'performance', 'between', 'the')
# 	Frequenza assoluta: 5
#
# Ngramma: ('mathematics', ',', 'reading', 'and', 'science')
# 	Frequenza assoluta: 5
#
# Ngramma: ('the', 'OECD', 'average', 'in', 'mathematics')
# 	Frequenza assoluta: 5
#
# Ngramma: (',', 'performance', 'in', 'numeracy', 'increased')
# 	Frequenza assoluta: 5
#
# Ngramma: (',', 'Hong', 'Kong', '(', 'China')
# 	Frequenza assoluta: 4
#
# Ngramma: ('(', 'China', ')', '*', ',')
# 	Frequenza assoluta: 4
#
# Ngramma: ('and', 'the', 'United', 'Kingdom', '*')
# 	Frequenza assoluta: 4
#
# Ngramma: ('IN',)
# 	Frequenza assoluta: 717
#
# Ngramma: ('NN',)
# 	Frequenza assoluta: 696
#
# Ngramma: ('NNS',)
# 	Frequenza assoluta: 538
#
# Ngramma: ('NNP',)
# 	Frequenza assoluta: 498
#
# Ngramma: ('JJ',)
# 	Frequenza assoluta: 347
#
# Ngramma: ('DT',)
# 	Frequenza assoluta: 328
#
# Ngramma: (',',)
# 	Frequenza assoluta: 298
#
# Ngramma: ('CD',)
# 	Frequenza assoluta: 269
#
# Ngramma: ('CC',)
# 	Frequenza assoluta: 217
#
# Ngramma: ('.',)
# 	Frequenza assoluta: 169
#
# Ngramma: ('RB',)
# 	Frequenza assoluta: 143
#
# Ngramma: ('VBD',)
# 	Frequenza assoluta: 106
#
# Ngramma: ('VBN',)
# 	Frequenza assoluta: 88
#
# Ngramma: ('VBZ',)
# 	Frequenza assoluta: 82
#
# Ngramma: ('VBP',)
# 	Frequenza assoluta: 80
#
# Ngramma: ('(',)
# 	Frequenza assoluta: 76
#
# Ngramma: (')',)
# 	Frequenza assoluta: 76
#
# Ngramma: ('TO',)
# 	Frequenza assoluta: 75
#
# Ngramma: ('VBG',)
# 	Frequenza assoluta: 70
#
# Ngramma: ('VB',)
# 	Frequenza assoluta: 56
#
# Ngramma: ('NN', 'IN')
# 	Frequenza assoluta: 224
#
# Ngramma: ('IN', 'DT')
# 	Frequenza assoluta: 152
#
# Ngramma: ('JJ', 'NN')
# 	Frequenza assoluta: 141
#
# Ngramma: ('IN', 'NN')
# 	Frequenza assoluta: 137
#
# Ngramma: ('NNS', 'IN')
# 	Frequenza assoluta: 129
#
# Ngramma: ('NNP', 'NNP')
# 	Frequenza assoluta: 128
#
# Ngramma: ('NNP', ',')
# 	Frequenza assoluta: 125
#
# Ngramma: ('DT', 'NN')
# 	Frequenza assoluta: 114
#
# Ngramma: (',', 'NNP')
# 	Frequenza assoluta: 113
#
# Ngramma: ('IN', 'NNS')
# 	Frequenza assoluta: 105
#
# Ngramma: ('JJ', 'NNS')
# 	Frequenza assoluta: 99
#
# Ngramma: ('CD', 'NNS')
# 	Frequenza assoluta: 89
#
# Ngramma: ('IN', 'CD')
# 	Frequenza assoluta: 83
#
# Ngramma: ('IN', 'NNP')
# 	Frequenza assoluta: 77
#
# Ngramma: ('IN', 'JJ')
# 	Frequenza assoluta: 75
#
# Ngramma: ('DT', 'JJ')
# 	Frequenza assoluta: 72
#
# Ngramma: ('CD', 'NN')
# 	Frequenza assoluta: 70
#
# Ngramma: ('NN', ',')
# 	Frequenza assoluta: 68
#
# Ngramma: ('NN', 'NNS')
# 	Frequenza assoluta: 62
#
# Ngramma: ('DT', 'NNP')
# 	Frequenza assoluta: 58
#
# Ngramma: ('NNP', ',', 'NNP')
# 	Frequenza assoluta: 98
#
# Ngramma: ('NN', 'IN', 'NN')
# 	Frequenza assoluta: 61
#
# Ngramma: ('JJ', 'NN', 'IN')
# 	Frequenza assoluta: 55
#
# Ngramma: ('DT', 'NN', 'IN')
# 	Frequenza assoluta: 54
#
# Ngramma: ('NN', 'IN', 'NNS')
# 	Frequenza assoluta: 53
#
# Ngramma: (',', 'NNP', ',')
# 	Frequenza assoluta: 53
#
# Ngramma: ('IN', 'DT', 'NN')
# 	Frequenza assoluta: 50
#
# Ngramma: ('DT', 'JJ', 'NN')
# 	Frequenza assoluta: 46
#
# Ngramma: ('NNP', 'NNP', ',')
# 	Frequenza assoluta: 39
#
# Ngramma: (',', 'NNP', 'NNP')
# 	Frequenza assoluta: 38
#
# Ngramma: ('NNP', 'NNP', 'NNP')
# 	Frequenza assoluta: 34
#
# Ngramma: ('NNS', 'CC', 'NNS')
# 	Frequenza assoluta: 33
#
# Ngramma: ('IN', 'DT', 'NNP')
# 	Frequenza assoluta: 32
#
# Ngramma: ('DT', 'NNP', 'NN')
# 	Frequenza assoluta: 31
#
# Ngramma: ('NN', 'IN', 'DT')
# 	Frequenza assoluta: 31
#
# Ngramma: ('JJ', 'NNS', 'IN')
# 	Frequenza assoluta: 31
#
# Ngramma: ('IN', 'DT', 'JJ')
# 	Frequenza assoluta: 30
#
# Ngramma: ('IN', 'CD', 'NNS')
# 	Frequenza assoluta: 30
#
# Ngramma: ('IN', 'JJ', 'NN')
# 	Frequenza assoluta: 29
#
# Ngramma: ('IN', 'NN', ',')
# 	Frequenza assoluta: 28
#
# Bigrammi: ('other', 'countries')
# 	Frequenza assoluta in ordine decrescente: 7
# Bigrammi: ('mean', 'score')
# 	Frequenza assoluta in ordine decrescente: 7
# Bigrammi: ('available', 'data')
# 	Frequenza assoluta in ordine decrescente: 5
# Bigrammi: ('high', 'levels')
# 	Frequenza assoluta in ordine decrescente: 4
# Bigrammi: ('average', 'performance')
# 	Frequenza assoluta in ordine decrescente: 4
# Bigrammi: ('other', 'countries/economies')
# 	Frequenza assoluta in ordine decrescente: 4
# Bigrammi: ('socio-economic', 'status')
# 	Frequenza assoluta in ordine decrescente: 4
# Bigrammi: ('lowest-performing', 'countries')
# 	Frequenza assoluta in ordine decrescente: 4
# Bigrammi: ('mean', 'scores')
# 	Frequenza assoluta in ordine decrescente: 4
# Bigrammi: ('Chinese', 'Taipei')
# 	Frequenza assoluta in ordine decrescente: 3
# Top 10 bigrammi per probabilità condizionata:
# 	 [(('common', 'features'), 1.0), (('shorter', 'school'), 1.0), (('Many', 'countries'), 1.0), (('secondary', 'education'), 1.0), (('socioeconomic', 'status'), 1.0), (('pandemic-induced', 'school'), 1.0), (('clear', 'difference'), 1.0), (('longer', 'school'), 1.0), (('global', 'conversion'), 1.0), (('enabled', 'remote'), 1.0)]
#
# Top 10 bigrammi per probabilità congiunta:
# 	 [(('OECD', 'countries'), 0.004062681369704005), (('Chinese', 'Taipei'), 0.0021280711936544788), (('Chinese', 'Taipei'), 0.0021280711936544788), (('Chinese', 'Taipei'), 0.0021280711936544788), (('student', 'performance'), 0.001934610176049526), (('mean', 'score'), 0.0019346101760495259), (('mean', 'score'), 0.0019346101760495259), (('mean', 'score'), 0.0019346101760495259), (('mean', 'score'), 0.0019346101760495259), (('mean', 'score'), 0.0019346101760495259)]
#
# Top 10 bigrammi per mutual information:
# 	 [(('common', 'features'), 12.335669486946104), (('global', 'conversion'), 12.335669486946104), (('defining', 'feature'), 12.335669486946104), (('video', 'communication'), 12.335669486946104), (('mobile', 'phones'), 12.335669486946104), (('good', 'access'), 12.335669486946104), (('initiated', 'discussions'), 12.335669486946104), (('cumulative', 'spending'), 12.335669486946104), (('align', 'resources'), 12.335669486946104), (('downward', 'descent'), 12.335669486946104)]
#
# Top 10 bigrammi per local mutual information:
# 	 [(('OECD', 'countries'), 99.47320747528194), (('Chinese', 'Taipei'), 97.63861655139688), (('Chinese', 'Taipei'), 97.63861655139688), (('Chinese', 'Taipei'), 97.63861655139688), (('student', 'performance'), 61.22322205212663), (('mean', 'score'), 60.55826793425757), (('mean', 'score'), 60.55826793425757), (('mean', 'score'), 60.55826793425757), (('mean', 'score'), 60.55826793425757), (('mean', 'score'), 60.55826793425757)]
#
# Non ci sono elementi in comune
# Il valore massimo di frequenza media appartiene alla frase: The decline in mathematics
# performance is three times greater than any previous consecutive change., con un valore di 1.0
# Il valore minimo di frequenza media appartiene alla frase: The decline in mathematics
# performance is three times greater than any previous consecutive change., con un valore di 1.0
# La probabilità massima secondo il Modello di Markov di ordine due appartiene alla frase: These students were also more confident than their peers to learn
# autonomously and remotely., con un valore di 0.0001934610176049526
# La probabilità minima secondo il Modello di Markov di ordine due appartiene alla frase: In science, the highest performing countries are
# the same six East Asian countries/economies, Canada* and Estonia., con un valore di 3.655352961053719e-10
# PERSON: Canada
# 	Frequenza assoluta: 9
# PERSON: Denmark
# 	Frequenza assoluta: 3
# PERSON: Macao
# 	Frequenza assoluta: 3
# PERSON: Finland
# 	Frequenza assoluta: 2
# PERSON: Singapore
# 	Frequenza assoluta: 2
# PERSON: Table
# 	Frequenza assoluta: 2
# PERSON: Costa Rica
# 	Frequenza assoluta: 1
# PERSON: Morocco
# 	Frequenza assoluta: 1
# PERSON: Czechia
# 	Frequenza assoluta: 1
# PERSON: Sweden
# 	Frequenza assoluta: 1
# PERSON: Jamaica
# 	Frequenza assoluta: 1
# PERSON: School
# 	Frequenza assoluta: 1
# PERSON: Brunei Darussalam
# 	Frequenza assoluta: 1
# PERSON: Peru
# 	Frequenza assoluta: 1
# PERSON: Qatar
# 	Frequenza assoluta: 1
# ORGANIZATION: OECD
# 	Frequenza assoluta: 56
# ORGANIZATION: PISA
# 	Frequenza assoluta: 38
# ORGANIZATION: PIAAC
# 	Frequenza assoluta: 6
# ORGANIZATION: United Kingdom
# 	Frequenza assoluta: 4
# ORGANIZATION: Table
# 	Frequenza assoluta: 4
# ORGANIZATION: Netherlands
# 	Frequenza assoluta: 3
# ORGANIZATION: Slovak Republic
# 	Frequenza assoluta: 3
# ORGANIZATION: Czech Republic
# 	Frequenza assoluta: 2
# ORGANIZATION: International Student Assessment
# 	Frequenza assoluta: 1
# ORGANIZATION: Paraguay
# 	Frequenza assoluta: 1
# ORGANIZATION: USD
# 	Frequenza assoluta: 1
# ORGANIZATION: PPP
# 	Frequenza assoluta: 1
# ORGANIZATION: OECD Members
# 	Frequenza assoluta: 1
# ORGANIZATION: Dominican Republic
# 	Frequenza assoluta: 1
# ORGANIZATION: Republic
# 	Frequenza assoluta: 1
# GPE: China
# 	Frequenza assoluta: 19
# GPE: Korea
# 	Frequenza assoluta: 15
# GPE: Japan
# 	Frequenza assoluta: 12
# GPE: Singapore
# 	Frequenza assoluta: 11
# GPE: Estonia
# 	Frequenza assoluta: 9
# GPE: Hong Kong
# 	Frequenza assoluta: 8
# GPE: Ireland
# 	Frequenza assoluta: 8
# GPE: Macao
# 	Frequenza assoluta: 8
# GPE: Chinese Taipei
# 	Frequenza assoluta: 7
# GPE: Belgium
# 	Frequenza assoluta: 6
# GPE: New Zealand
# 	Frequenza assoluta: 6
# GPE: Australia
# 	Frequenza assoluta: 5
# GPE: Finland
# 	Frequenza assoluta: 5
# GPE: Latvia
# 	Frequenza assoluta: 4
# GPE: Chinese
# 	Frequenza assoluta: 4
